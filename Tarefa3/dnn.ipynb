# %% [markdown]
# # Aprendizem Profunda - DNN
# ### Tarefa III
# 1. Rúben Gonçalo Araújo da Silva pg57900
# 2. José Luis Fraga Costa pg55970
# 3. Pedro Miguel Costa Azevedo pg57897
# 4. Rui Pedro Fernandes Madeira Pinto pg56010

# %% [markdown]
# # Implementação

# %% [markdown]
# ### imports
#
# 1. pandas
# 2. tensorflow
# 3. sklearn

# %%
# Standard Library
import os
import csv

# Data Handling
import pandas as pd
import numpy as np

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# TensorFlow / Keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Embedding, Flatten, Dense, Dropout, SimpleRNN, GRU, LSTM, 
    Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D, 
    BatchNormalization, LeakyReLU, Input
)
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

# Hugging Face Transformers
from transformers import (
    AutoTokenizer, 
    TFAutoModelForSequenceClassification, 
    pipeline
)

# %% [markdown]
# ### Input dos dados

# %%
df = pd.read_csv("data/small_dataset.csv")
df = df.dropna(subset=["Label"])
df["Text"] = df["Text"].fillna("")
all_ids = df["ID"].fillna("")
test_ids = df["ID"].fillna("")

# %% [markdown]
# ### Função pra gravar em csv

# %%
def to_csv(results_df, name):
    os.makedirs("submissao2", exist_ok=True)
    path = f"submissao2/{name}.csv"
    filtered_df = results_df[results_df["ID"].notna() & (results_df["ID"] != "")].copy()
    filtered_df['prefix'] = filtered_df['ID'].str.extract(r'(D[0-9])')
    filtered_df['number'] = filtered_df['ID'].str.extract(r'-(\d+)').astype(int)
    filtered_df = filtered_df.sort_values(by=['prefix', 'number'])

    with open(path, 'w') as f:
        f.write("ID\tLabel\n") 
        for index, row in filtered_df.iterrows():
            f.write(f"{row['ID']}\t{row['Label']}\n")

# %%
def predict_and_save(model, X_data, ids, model_name):
    # Generate predictions
    y_pred = (model.predict(X_data) > 0.5).astype(int).flatten()

    # Convert numeric predictions to labels
    labels = ["Human" if label == 0 else "AI" for label in y_pred]
    # Create results DataFrame
    results_df = pd.DataFrame({
        "ID": ids,
        "Label": labels
    })
    to_csv(results_df, model_name)

# %% [markdown]
# ### Train Test Split (divisão de dados)

# %%
# Remove duplicates by keeping the first occurrence
df_unique = df.drop_duplicates(subset=["Text"], keep="first")

# Check how many rows remain
print(f"Original dataset size: {len(df)}, Unique texts: {len(df_unique)}")

# Split the deduplicated dataset
train_texts, test_texts, train_labels, test_labels = train_test_split(
    df_unique["Text"], df_unique["Label"], test_size=0.2, random_state=42, stratify=df_unique["Label"]
)
test_indices = test_texts.index

train_texts, val_texts, train_labels, val_labels = train_test_split(
    train_texts, train_labels, test_size=0.2, random_state=42, stratify=train_labels
)

# Verify no overlap
print(f"Overlap between train and test after deduplication: {len(set(train_texts) & set(test_texts))}")
# Out:
# Original dataset size: 4053, Unique texts: 4051
# Overlap between train and test after deduplication: 0

# %% [markdown]
# ### Tokenizer

# %%
# Tokenize the data
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(train_texts)

X_train_seq = tokenizer.texts_to_sequences(train_texts)
X_val_seq = tokenizer.texts_to_sequences(val_texts)
X_test_seq = tokenizer.texts_to_sequences(test_texts)

X_train = pad_sequences(X_train_seq, maxlen=100)
X_val = pad_sequences(X_val_seq, maxlen=100)
X_test = pad_sequences(X_test_seq, maxlen=100)

# Convert string labels to numeric values
label_map = {"Human": 0, "AI": 1}  # Define mapping
y_train = np.array([label_map[label] for label in train_labels], dtype=np.float32)
y_val = np.array([label_map[label] for label in val_labels], dtype=np.float32)
y_test = np.array([label_map[label] for label in test_labels], dtype=np.float32)

# %% [markdown]
# ## Dataset de Avaliação

# %%
data_set_professor = pd.read_csv("data/dataset3_inputs.csv", sep=';', on_bad_lines='skip')
data_set_professor["Text"] = data_set_professor["Text"].fillna("")
X_professor_seq = tokenizer.texts_to_sequences(data_set_professor["Text"])
X_professor = pad_sequences(X_professor_seq, maxlen=100)

# %% [markdown]
# ### Early Stopping

# %%
early_stopping = EarlyStopping(
    monitor='val_loss',     
    patience=10,            
    restore_best_weights=True,           
)

# %% [markdown]
# ### Reduce_lr

# %%
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5, 
    patience=3,
    min_lr=0.00005
)

# %% [markdown]
# ## DNN

# %%
model_dnn = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(128, kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    Dropout(0.5),
    Dense(64, kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    Dropout(0.5),
    Dense(32, kernel_regularizer=l2(0.001)),
    BatchNormalization(),
    LeakyReLU(alpha=0.1),
    Dropout(0.5),
    Dense(1, activation="sigmoid"),
])

# Compile
model_dnn.compile(optimizer=Adam(learning_rate=0.0001), loss="binary_crossentropy", metrics=["accuracy"])

# Train
history = model_dnn.fit(
    X_train, y_train,
    epochs=200,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, reduce_lr],
    shuffle=True
)
# Out:
# Epoch 1/200
# c:\Users\ruben\Desktop\Minho\MEI\SI\AP\.venv\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5050 - loss: 1.1054 - val_accuracy: 0.5849 - val_loss: 0.9203 - learning_rate: 1.0000e-04
# Epoch 2/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5575 - loss: 1.0278 - val_accuracy: 0.6250 - val_loss: 0.8953 - learning_rate: 1.0000e-04
# Epoch 3/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5512 - loss: 1.0320 - val_accuracy: 0.6682 - val_loss: 0.8777 - learning_rate: 1.0000e-04
# Epoch 4/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5911 - loss: 0.9683 - val_accuracy: 0.6806 - val_loss: 0.8636 - learning_rate: 1.0000e-04
# Epoch 5/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5832 - loss: 0.9837 - val_accuracy: 0.6821 - val_loss: 0.8527 - learning_rate: 1.0000e-04
# Epoch 6/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5907 - loss: 0.9669 - val_accuracy: 0.6883 - val_loss: 0.8426 - learning_rate: 1.0000e-04
# Epoch 7/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5954 - loss: 0.9578 - val_accuracy: 0.6883 - val_loss: 0.8346 - learning_rate: 1.0000e-04
# Epoch 8/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6077 - loss: 0.9388 - val_accuracy: 0.6867 - val_loss: 0.8281 - learning_rate: 1.0000e-04
# Epoch 9/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6431 - loss: 0.9069 - val_accuracy: 0.6944 - val_loss: 0.8228 - learning_rate: 1.0000e-04
# Epoch 10/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6316 - loss: 0.9195 - val_accuracy: 0.6898 - val_loss: 0.8179 - learning_rate: 1.0000e-04
# Epoch 11/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6467 - loss: 0.8926 - val_accuracy: 0.6914 - val_loss: 0.8140 - learning_rate: 1.0000e-04
# Epoch 12/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6278 - loss: 0.9085 - val_accuracy: 0.6944 - val_loss: 0.8107 - learning_rate: 1.0000e-04
# Epoch 13/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6525 - loss: 0.9014 - val_accuracy: 0.6929 - val_loss: 0.8072 - learning_rate: 1.0000e-04
# Epoch 14/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6543 - loss: 0.8895 - val_accuracy: 0.6944 - val_loss: 0.8050 - learning_rate: 1.0000e-04
# Epoch 15/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6666 - loss: 0.8599 - val_accuracy: 0.6944 - val_loss: 0.8022 - learning_rate: 1.0000e-04
# Epoch 16/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6665 - loss: 0.8646 - val_accuracy: 0.6975 - val_loss: 0.7983 - learning_rate: 1.0000e-04
# Epoch 17/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6798 - loss: 0.8398 - val_accuracy: 0.6991 - val_loss: 0.7961 - learning_rate: 1.0000e-04
# Epoch 18/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6866 - loss: 0.8383 - val_accuracy: 0.6914 - val_loss: 0.7963 - learning_rate: 1.0000e-04
# Epoch 19/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6659 - loss: 0.8754 - val_accuracy: 0.6960 - val_loss: 0.7946 - learning_rate: 1.0000e-04
# Epoch 20/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6966 - loss: 0.8322 - val_accuracy: 0.6944 - val_loss: 0.7920 - learning_rate: 1.0000e-04
# Epoch 21/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6767 - loss: 0.8628 - val_accuracy: 0.6944 - val_loss: 0.7909 - learning_rate: 1.0000e-04
# Epoch 22/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6846 - loss: 0.8462 - val_accuracy: 0.7022 - val_loss: 0.7878 - learning_rate: 1.0000e-04
# Epoch 23/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6955 - loss: 0.8068 - val_accuracy: 0.7068 - val_loss: 0.7845 - learning_rate: 1.0000e-04
# Epoch 24/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6996 - loss: 0.8269 - val_accuracy: 0.6991 - val_loss: 0.7861 - learning_rate: 1.0000e-04
# Epoch 25/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6908 - loss: 0.8178 - val_accuracy: 0.6975 - val_loss: 0.7857 - learning_rate: 1.0000e-04
# Epoch 26/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7193 - loss: 0.8107 - val_accuracy: 0.6960 - val_loss: 0.7861 - learning_rate: 1.0000e-04
# Epoch 27/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7054 - loss: 0.7960 - val_accuracy: 0.6914 - val_loss: 0.7861 - learning_rate: 5.0000e-05
# Epoch 28/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7121 - loss: 0.8162 - val_accuracy: 0.6914 - val_loss: 0.7865 - learning_rate: 5.0000e-05
# Epoch 29/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7227 - loss: 0.7803 - val_accuracy: 0.6975 - val_loss: 0.7838 - learning_rate: 5.0000e-05
# Epoch 30/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7017 - loss: 0.8137 - val_accuracy: 0.6960 - val_loss: 0.7838 - learning_rate: 5.0000e-05
# Epoch 31/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7346 - loss: 0.7843 - val_accuracy: 0.6929 - val_loss: 0.7850 - learning_rate: 5.0000e-05
# Epoch 32/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7141 - loss: 0.7975 - val_accuracy: 0.6960 - val_loss: 0.7835 - learning_rate: 5.0000e-05
# Epoch 33/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7166 - loss: 0.7939 - val_accuracy: 0.6975 - val_loss: 0.7825 - learning_rate: 5.0000e-05
# Epoch 34/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7378 - loss: 0.7602 - val_accuracy: 0.6991 - val_loss: 0.7818 - learning_rate: 5.0000e-05
# Epoch 35/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7160 - loss: 0.7908 - val_accuracy: 0.6975 - val_loss: 0.7801 - learning_rate: 5.0000e-05
# Epoch 36/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7214 - loss: 0.7948 - val_accuracy: 0.7006 - val_loss: 0.7788 - learning_rate: 5.0000e-05
# Epoch 37/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7069 - loss: 0.7946 - val_accuracy: 0.6991 - val_loss: 0.7800 - learning_rate: 5.0000e-05
# Epoch 38/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7208 - loss: 0.7696 - val_accuracy: 0.6975 - val_loss: 0.7792 - learning_rate: 5.0000e-05
# Epoch 39/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7261 - loss: 0.7777 - val_accuracy: 0.6991 - val_loss: 0.7766 - learning_rate: 5.0000e-05
# Epoch 40/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7140 - loss: 0.8006 - val_accuracy: 0.7006 - val_loss: 0.7768 - learning_rate: 5.0000e-05
# Epoch 41/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7122 - loss: 0.7883 - val_accuracy: 0.6991 - val_loss: 0.7765 - learning_rate: 5.0000e-05
# Epoch 42/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7339 - loss: 0.7827 - val_accuracy: 0.6975 - val_loss: 0.7754 - learning_rate: 5.0000e-05
# Epoch 43/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7193 - loss: 0.7709 - val_accuracy: 0.6944 - val_loss: 0.7764 - learning_rate: 5.0000e-05
# Epoch 44/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7230 - loss: 0.7823 - val_accuracy: 0.6960 - val_loss: 0.7762 - learning_rate: 5.0000e-05
# Epoch 45/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7384 - loss: 0.7884 - val_accuracy: 0.7006 - val_loss: 0.7726 - learning_rate: 5.0000e-05
# Epoch 46/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7387 - loss: 0.7557 - val_accuracy: 0.7037 - val_loss: 0.7720 - learning_rate: 5.0000e-05
# Epoch 47/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7421 - loss: 0.7592 - val_accuracy: 0.7022 - val_loss: 0.7709 - learning_rate: 5.0000e-05
# Epoch 48/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7343 - loss: 0.7685 - val_accuracy: 0.6991 - val_loss: 0.7718 - learning_rate: 5.0000e-05
# Epoch 49/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7306 - loss: 0.7519 - val_accuracy: 0.6991 - val_loss: 0.7714 - learning_rate: 5.0000e-05
# Epoch 50/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7255 - loss: 0.7762 - val_accuracy: 0.6991 - val_loss: 0.7709 - learning_rate: 5.0000e-05
# Epoch 51/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7478 - loss: 0.7498 - val_accuracy: 0.6991 - val_loss: 0.7705 - learning_rate: 5.0000e-05
# Epoch 52/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7472 - loss: 0.7392 - val_accuracy: 0.7052 - val_loss: 0.7683 - learning_rate: 5.0000e-05
# Epoch 53/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7261 - loss: 0.7689 - val_accuracy: 0.7068 - val_loss: 0.7673 - learning_rate: 5.0000e-05
# Epoch 54/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7250 - loss: 0.7614 - val_accuracy: 0.7099 - val_loss: 0.7658 - learning_rate: 5.0000e-05
# Epoch 55/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7267 - loss: 0.7632 - val_accuracy: 0.7099 - val_loss: 0.7620 - learning_rate: 5.0000e-05
# Epoch 56/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7337 - loss: 0.7645 - val_accuracy: 0.7114 - val_loss: 0.7640 - learning_rate: 5.0000e-05
# Epoch 57/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7531 - loss: 0.7179 - val_accuracy: 0.7083 - val_loss: 0.7638 - learning_rate: 5.0000e-05
# Epoch 58/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7632 - loss: 0.7356 - val_accuracy: 0.7130 - val_loss: 0.7614 - learning_rate: 5.0000e-05
# Epoch 59/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7230 - loss: 0.7686 - val_accuracy: 0.7145 - val_loss: 0.7601 - learning_rate: 5.0000e-05
# Epoch 60/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7395 - loss: 0.7567 - val_accuracy: 0.7160 - val_loss: 0.7584 - learning_rate: 5.0000e-05
# Epoch 61/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7494 - loss: 0.7369 - val_accuracy: 0.7191 - val_loss: 0.7568 - learning_rate: 5.0000e-05
# Epoch 62/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7352 - loss: 0.7644 - val_accuracy: 0.7160 - val_loss: 0.7571 - learning_rate: 5.0000e-05
# Epoch 63/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7517 - loss: 0.7329 - val_accuracy: 0.7130 - val_loss: 0.7595 - learning_rate: 5.0000e-05
# Epoch 64/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7235 - loss: 0.7586 - val_accuracy: 0.7145 - val_loss: 0.7584 - learning_rate: 5.0000e-05
# Epoch 65/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7292 - loss: 0.7581 - val_accuracy: 0.7145 - val_loss: 0.7583 - learning_rate: 5.0000e-05
# Epoch 66/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7596 - loss: 0.7224 - val_accuracy: 0.7145 - val_loss: 0.7579 - learning_rate: 5.0000e-05
# Epoch 67/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7459 - loss: 0.7380 - val_accuracy: 0.7160 - val_loss: 0.7544 - learning_rate: 5.0000e-05
# Epoch 68/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7336 - loss: 0.7445 - val_accuracy: 0.7145 - val_loss: 0.7559 - learning_rate: 5.0000e-05
# Epoch 69/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7461 - loss: 0.7493 - val_accuracy: 0.7145 - val_loss: 0.7554 - learning_rate: 5.0000e-05
# Epoch 70/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7517 - loss: 0.7553 - val_accuracy: 0.7114 - val_loss: 0.7565 - learning_rate: 5.0000e-05
# Epoch 71/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7475 - loss: 0.7291 - val_accuracy: 0.7130 - val_loss: 0.7553 - learning_rate: 5.0000e-05
# Epoch 72/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7564 - loss: 0.7120 - val_accuracy: 0.7160 - val_loss: 0.7526 - learning_rate: 5.0000e-05
# Epoch 73/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7632 - loss: 0.7163 - val_accuracy: 0.7145 - val_loss: 0.7521 - learning_rate: 5.0000e-05
# Epoch 74/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7667 - loss: 0.7108 - val_accuracy: 0.7160 - val_loss: 0.7505 - learning_rate: 5.0000e-05
# Epoch 75/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7685 - loss: 0.6930 - val_accuracy: 0.7176 - val_loss: 0.7498 - learning_rate: 5.0000e-05
# Epoch 76/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7626 - loss: 0.7101 - val_accuracy: 0.7130 - val_loss: 0.7507 - learning_rate: 5.0000e-05
# Epoch 77/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7560 - loss: 0.7233 - val_accuracy: 0.7130 - val_loss: 0.7496 - learning_rate: 5.0000e-05
# Epoch 78/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7613 - loss: 0.7108 - val_accuracy: 0.7160 - val_loss: 0.7482 - learning_rate: 5.0000e-05
# Epoch 79/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7566 - loss: 0.7107 - val_accuracy: 0.7207 - val_loss: 0.7469 - learning_rate: 5.0000e-05
# Epoch 80/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7678 - loss: 0.7184 - val_accuracy: 0.7160 - val_loss: 0.7479 - learning_rate: 5.0000e-05
# Epoch 81/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7467 - loss: 0.7307 - val_accuracy: 0.7176 - val_loss: 0.7469 - learning_rate: 5.0000e-05
# Epoch 82/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7511 - loss: 0.7190 - val_accuracy: 0.7191 - val_loss: 0.7463 - learning_rate: 5.0000e-05
# Epoch 83/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7635 - loss: 0.7169 - val_accuracy: 0.7222 - val_loss: 0.7435 - learning_rate: 5.0000e-05
# Epoch 84/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7575 - loss: 0.7121 - val_accuracy: 0.7207 - val_loss: 0.7433 - learning_rate: 5.0000e-05
# Epoch 85/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7539 - loss: 0.7045 - val_accuracy: 0.7176 - val_loss: 0.7427 - learning_rate: 5.0000e-05
# Epoch 86/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7687 - loss: 0.7160 - val_accuracy: 0.7176 - val_loss: 0.7424 - learning_rate: 5.0000e-05
# Epoch 87/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7651 - loss: 0.7120 - val_accuracy: 0.7176 - val_loss: 0.7433 - learning_rate: 5.0000e-05
# Epoch 88/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7749 - loss: 0.7144 - val_accuracy: 0.7176 - val_loss: 0.7425 - learning_rate: 5.0000e-05
# Epoch 89/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7579 - loss: 0.7133 - val_accuracy: 0.7176 - val_loss: 0.7411 - learning_rate: 5.0000e-05
# Epoch 90/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7750 - loss: 0.6895 - val_accuracy: 0.7207 - val_loss: 0.7392 - learning_rate: 5.0000e-05
# Epoch 91/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7805 - loss: 0.6869 - val_accuracy: 0.7207 - val_loss: 0.7388 - learning_rate: 5.0000e-05
# Epoch 92/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7587 - loss: 0.7083 - val_accuracy: 0.7222 - val_loss: 0.7376 - learning_rate: 5.0000e-05
# Epoch 93/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7635 - loss: 0.6967 - val_accuracy: 0.7207 - val_loss: 0.7398 - learning_rate: 5.0000e-05
# Epoch 94/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7575 - loss: 0.7119 - val_accuracy: 0.7238 - val_loss: 0.7362 - learning_rate: 5.0000e-05
# Epoch 95/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7647 - loss: 0.6956 - val_accuracy: 0.7253 - val_loss: 0.7345 - learning_rate: 5.0000e-05
# Epoch 96/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7642 - loss: 0.6985 - val_accuracy: 0.7253 - val_loss: 0.7342 - learning_rate: 5.0000e-05
# Epoch 97/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7986 - loss: 0.6700 - val_accuracy: 0.7238 - val_loss: 0.7347 - learning_rate: 5.0000e-05
# Epoch 98/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7780 - loss: 0.6866 - val_accuracy: 0.7238 - val_loss: 0.7340 - learning_rate: 5.0000e-05
# Epoch 99/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7583 - loss: 0.7086 - val_accuracy: 0.7269 - val_loss: 0.7329 - learning_rate: 5.0000e-05
# Epoch 100/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7730 - loss: 0.6800 - val_accuracy: 0.7253 - val_loss: 0.7318 - learning_rate: 5.0000e-05
# Epoch 101/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7882 - loss: 0.6649 - val_accuracy: 0.7269 - val_loss: 0.7310 - learning_rate: 5.0000e-05
# Epoch 102/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7869 - loss: 0.6782 - val_accuracy: 0.7253 - val_loss: 0.7301 - learning_rate: 5.0000e-05
# Epoch 103/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7824 - loss: 0.6810 - val_accuracy: 0.7269 - val_loss: 0.7280 - learning_rate: 5.0000e-05
# Epoch 104/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7730 - loss: 0.6694 - val_accuracy: 0.7269 - val_loss: 0.7256 - learning_rate: 5.0000e-05
# Epoch 105/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7677 - loss: 0.7026 - val_accuracy: 0.7269 - val_loss: 0.7258 - learning_rate: 5.0000e-05
# Epoch 106/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7681 - loss: 0.7025 - val_accuracy: 0.7253 - val_loss: 0.7267 - learning_rate: 5.0000e-05
# Epoch 107/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7775 - loss: 0.6693 - val_accuracy: 0.7253 - val_loss: 0.7257 - learning_rate: 5.0000e-05
# Epoch 108/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7556 - loss: 0.6848 - val_accuracy: 0.7238 - val_loss: 0.7237 - learning_rate: 5.0000e-05
# Epoch 109/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7699 - loss: 0.6863 - val_accuracy: 0.7238 - val_loss: 0.7247 - learning_rate: 5.0000e-05
# Epoch 110/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7790 - loss: 0.6803 - val_accuracy: 0.7253 - val_loss: 0.7216 - learning_rate: 5.0000e-05
# Epoch 111/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7849 - loss: 0.6724 - val_accuracy: 0.7253 - val_loss: 0.7208 - learning_rate: 5.0000e-05
# Epoch 112/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7780 - loss: 0.6658 - val_accuracy: 0.7238 - val_loss: 0.7206 - learning_rate: 5.0000e-05
# Epoch 113/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7841 - loss: 0.6640 - val_accuracy: 0.7253 - val_loss: 0.7203 - learning_rate: 5.0000e-05
# Epoch 114/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7734 - loss: 0.6829 - val_accuracy: 0.7253 - val_loss: 0.7186 - learning_rate: 5.0000e-05
# Epoch 115/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7864 - loss: 0.6780 - val_accuracy: 0.7269 - val_loss: 0.7196 - learning_rate: 5.0000e-05
# Epoch 116/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7662 - loss: 0.6895 - val_accuracy: 0.7238 - val_loss: 0.7195 - learning_rate: 5.0000e-05
# Epoch 117/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7602 - loss: 0.6810 - val_accuracy: 0.7238 - val_loss: 0.7193 - learning_rate: 5.0000e-05
# Epoch 118/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7946 - loss: 0.6628 - val_accuracy: 0.7238 - val_loss: 0.7192 - learning_rate: 5.0000e-05
# Epoch 119/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7732 - loss: 0.6675 - val_accuracy: 0.7253 - val_loss: 0.7160 - learning_rate: 5.0000e-05
# Epoch 120/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7956 - loss: 0.6591 - val_accuracy: 0.7238 - val_loss: 0.7165 - learning_rate: 5.0000e-05
# Epoch 121/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7821 - loss: 0.6560 - val_accuracy: 0.7284 - val_loss: 0.7153 - learning_rate: 5.0000e-05
# Epoch 122/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7903 - loss: 0.6766 - val_accuracy: 0.7253 - val_loss: 0.7149 - learning_rate: 5.0000e-05
# Epoch 123/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7834 - loss: 0.6623 - val_accuracy: 0.7284 - val_loss: 0.7135 - learning_rate: 5.0000e-05
# Epoch 124/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7750 - loss: 0.6678 - val_accuracy: 0.7253 - val_loss: 0.7142 - learning_rate: 5.0000e-05
# Epoch 125/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7785 - loss: 0.6524 - val_accuracy: 0.7299 - val_loss: 0.7124 - learning_rate: 5.0000e-05
# Epoch 126/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7631 - loss: 0.6606 - val_accuracy: 0.7269 - val_loss: 0.7123 - learning_rate: 5.0000e-05
# Epoch 127/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7798 - loss: 0.6611 - val_accuracy: 0.7284 - val_loss: 0.7106 - learning_rate: 5.0000e-05
# Epoch 128/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7782 - loss: 0.6695 - val_accuracy: 0.7284 - val_loss: 0.7094 - learning_rate: 5.0000e-05
# Epoch 129/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7916 - loss: 0.6579 - val_accuracy: 0.7269 - val_loss: 0.7090 - learning_rate: 5.0000e-05
# Epoch 130/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7642 - loss: 0.6826 - val_accuracy: 0.7269 - val_loss: 0.7075 - learning_rate: 5.0000e-05
# Epoch 131/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7900 - loss: 0.6480 - val_accuracy: 0.7284 - val_loss: 0.7084 - learning_rate: 5.0000e-05
# Epoch 132/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7757 - loss: 0.6598 - val_accuracy: 0.7269 - val_loss: 0.7092 - learning_rate: 5.0000e-05
# Epoch 133/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7861 - loss: 0.6473 - val_accuracy: 0.7284 - val_loss: 0.7062 - learning_rate: 5.0000e-05
# Epoch 134/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7876 - loss: 0.6724 - val_accuracy: 0.7284 - val_loss: 0.7053 - learning_rate: 5.0000e-05
# Epoch 135/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7862 - loss: 0.6532 - val_accuracy: 0.7269 - val_loss: 0.7050 - learning_rate: 5.0000e-05
# Epoch 136/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7933 - loss: 0.6562 - val_accuracy: 0.7253 - val_loss: 0.7049 - learning_rate: 5.0000e-05
# Epoch 137/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7772 - loss: 0.6560 - val_accuracy: 0.7253 - val_loss: 0.7049 - learning_rate: 5.0000e-05
# Epoch 138/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7870 - loss: 0.6493 - val_accuracy: 0.7253 - val_loss: 0.7037 - learning_rate: 5.0000e-05
# Epoch 139/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7952 - loss: 0.6292 - val_accuracy: 0.7253 - val_loss: 0.7040 - learning_rate: 5.0000e-05
# Epoch 140/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7981 - loss: 0.6406 - val_accuracy: 0.7269 - val_loss: 0.7030 - learning_rate: 5.0000e-05
# Epoch 141/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8037 - loss: 0.6262 - val_accuracy: 0.7269 - val_loss: 0.7028 - learning_rate: 5.0000e-05
# Epoch 142/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7907 - loss: 0.6465 - val_accuracy: 0.7269 - val_loss: 0.7004 - learning_rate: 5.0000e-05
# Epoch 143/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7804 - loss: 0.6591 - val_accuracy: 0.7299 - val_loss: 0.6995 - learning_rate: 5.0000e-05
# Epoch 144/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7783 - loss: 0.6504 - val_accuracy: 0.7299 - val_loss: 0.6993 - learning_rate: 5.0000e-05
# Epoch 145/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7949 - loss: 0.6498 - val_accuracy: 0.7284 - val_loss: 0.6993 - learning_rate: 5.0000e-05
# Epoch 146/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8021 - loss: 0.6350 - val_accuracy: 0.7284 - val_loss: 0.6990 - learning_rate: 5.0000e-05
# Epoch 147/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7950 - loss: 0.6366 - val_accuracy: 0.7284 - val_loss: 0.6979 - learning_rate: 5.0000e-05
# Epoch 148/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7974 - loss: 0.6380 - val_accuracy: 0.7253 - val_loss: 0.6983 - learning_rate: 5.0000e-05
# Epoch 149/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8042 - loss: 0.6230 - val_accuracy: 0.7253 - val_loss: 0.6979 - learning_rate: 5.0000e-05
# Epoch 150/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7924 - loss: 0.6455 - val_accuracy: 0.7315 - val_loss: 0.6963 - learning_rate: 5.0000e-05
# Epoch 151/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8087 - loss: 0.6223 - val_accuracy: 0.7330 - val_loss: 0.6949 - learning_rate: 5.0000e-05
# Epoch 152/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8003 - loss: 0.6219 - val_accuracy: 0.7361 - val_loss: 0.6940 - learning_rate: 5.0000e-05
# Epoch 153/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7792 - loss: 0.6540 - val_accuracy: 0.7377 - val_loss: 0.6931 - learning_rate: 5.0000e-05
# Epoch 154/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7883 - loss: 0.6495 - val_accuracy: 0.7361 - val_loss: 0.6926 - learning_rate: 5.0000e-05
# Epoch 155/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7942 - loss: 0.6369 - val_accuracy: 0.7330 - val_loss: 0.6923 - learning_rate: 5.0000e-05
# Epoch 156/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7806 - loss: 0.6426 - val_accuracy: 0.7315 - val_loss: 0.6925 - learning_rate: 5.0000e-05
# Epoch 157/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8040 - loss: 0.6278 - val_accuracy: 0.7330 - val_loss: 0.6915 - learning_rate: 5.0000e-05
# Epoch 158/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7925 - loss: 0.6319 - val_accuracy: 0.7299 - val_loss: 0.6929 - learning_rate: 5.0000e-05
# Epoch 159/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7924 - loss: 0.6403 - val_accuracy: 0.7346 - val_loss: 0.6909 - learning_rate: 5.0000e-05
# Epoch 160/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7764 - loss: 0.6411 - val_accuracy: 0.7346 - val_loss: 0.6909 - learning_rate: 5.0000e-05
# Epoch 161/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7938 - loss: 0.6432 - val_accuracy: 0.7346 - val_loss: 0.6908 - learning_rate: 5.0000e-05
# Epoch 162/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7951 - loss: 0.6224 - val_accuracy: 0.7423 - val_loss: 0.6885 - learning_rate: 5.0000e-05
# Epoch 163/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7950 - loss: 0.6303 - val_accuracy: 0.7346 - val_loss: 0.6886 - learning_rate: 5.0000e-05
# Epoch 164/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8001 - loss: 0.6126 - val_accuracy: 0.7361 - val_loss: 0.6892 - learning_rate: 5.0000e-05
# Epoch 165/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7969 - loss: 0.6431 - val_accuracy: 0.7407 - val_loss: 0.6862 - learning_rate: 5.0000e-05
# Epoch 166/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8043 - loss: 0.6145 - val_accuracy: 0.7377 - val_loss: 0.6872 - learning_rate: 5.0000e-05
# Epoch 167/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7842 - loss: 0.6178 - val_accuracy: 0.7407 - val_loss: 0.6862 - learning_rate: 5.0000e-05
# Epoch 168/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8061 - loss: 0.6136 - val_accuracy: 0.7377 - val_loss: 0.6870 - learning_rate: 5.0000e-05
# Epoch 169/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8072 - loss: 0.6119 - val_accuracy: 0.7392 - val_loss: 0.6857 - learning_rate: 5.0000e-05
# Epoch 170/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7978 - loss: 0.6120 - val_accuracy: 0.7361 - val_loss: 0.6867 - learning_rate: 5.0000e-05
# Epoch 171/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7897 - loss: 0.6273 - val_accuracy: 0.7392 - val_loss: 0.6849 - learning_rate: 5.0000e-05
# Epoch 172/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7911 - loss: 0.6207 - val_accuracy: 0.7392 - val_loss: 0.6839 - learning_rate: 5.0000e-05
# Epoch 173/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7944 - loss: 0.6211 - val_accuracy: 0.7392 - val_loss: 0.6838 - learning_rate: 5.0000e-05
# Epoch 174/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8035 - loss: 0.6189 - val_accuracy: 0.7392 - val_loss: 0.6833 - learning_rate: 5.0000e-05
# Epoch 175/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8037 - loss: 0.6107 - val_accuracy: 0.7392 - val_loss: 0.6835 - learning_rate: 5.0000e-05
# Epoch 176/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7935 - loss: 0.6138 - val_accuracy: 0.7407 - val_loss: 0.6808 - learning_rate: 5.0000e-05
# Epoch 177/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8043 - loss: 0.6298 - val_accuracy: 0.7407 - val_loss: 0.6810 - learning_rate: 5.0000e-05
# Epoch 178/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7924 - loss: 0.6226 - val_accuracy: 0.7392 - val_loss: 0.6815 - learning_rate: 5.0000e-05
# Epoch 179/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8066 - loss: 0.5912 - val_accuracy: 0.7407 - val_loss: 0.6807 - learning_rate: 5.0000e-05
# Epoch 180/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7917 - loss: 0.6299 - val_accuracy: 0.7407 - val_loss: 0.6798 - learning_rate: 5.0000e-05
# Epoch 181/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8019 - loss: 0.5995 - val_accuracy: 0.7392 - val_loss: 0.6815 - learning_rate: 5.0000e-05
# Epoch 182/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8012 - loss: 0.6013 - val_accuracy: 0.7407 - val_loss: 0.6789 - learning_rate: 5.0000e-05
# Epoch 183/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8004 - loss: 0.6054 - val_accuracy: 0.7407 - val_loss: 0.6783 - learning_rate: 5.0000e-05
# Epoch 184/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8014 - loss: 0.5970 - val_accuracy: 0.7407 - val_loss: 0.6770 - learning_rate: 5.0000e-05
# Epoch 185/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8021 - loss: 0.6174 - val_accuracy: 0.7407 - val_loss: 0.6765 - learning_rate: 5.0000e-05
# Epoch 186/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8063 - loss: 0.5956 - val_accuracy: 0.7407 - val_loss: 0.6771 - learning_rate: 5.0000e-05
# Epoch 187/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8154 - loss: 0.6000 - val_accuracy: 0.7407 - val_loss: 0.6767 - learning_rate: 5.0000e-05
# Epoch 188/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7996 - loss: 0.6107 - val_accuracy: 0.7407 - val_loss: 0.6765 - learning_rate: 5.0000e-05
# Epoch 189/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8195 - loss: 0.5787 - val_accuracy: 0.7407 - val_loss: 0.6764 - learning_rate: 5.0000e-05
# Epoch 190/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7965 - loss: 0.6206 - val_accuracy: 0.7423 - val_loss: 0.6763 - learning_rate: 5.0000e-05
# Epoch 191/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8063 - loss: 0.6036 - val_accuracy: 0.7423 - val_loss: 0.6759 - learning_rate: 5.0000e-05
# Epoch 192/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8141 - loss: 0.5765 - val_accuracy: 0.7423 - val_loss: 0.6762 - learning_rate: 5.0000e-05
# Epoch 193/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7945 - loss: 0.6232 - val_accuracy: 0.7392 - val_loss: 0.6766 - learning_rate: 5.0000e-05
# Epoch 194/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8062 - loss: 0.6117 - val_accuracy: 0.7407 - val_loss: 0.6753 - learning_rate: 5.0000e-05
# Epoch 195/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8123 - loss: 0.5873 - val_accuracy: 0.7392 - val_loss: 0.6761 - learning_rate: 5.0000e-05
# Epoch 196/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7942 - loss: 0.6071 - val_accuracy: 0.7392 - val_loss: 0.6757 - learning_rate: 5.0000e-05
# Epoch 197/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8044 - loss: 0.6013 - val_accuracy: 0.7407 - val_loss: 0.6746 - learning_rate: 5.0000e-05
# Epoch 198/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8068 - loss: 0.5857 - val_accuracy: 0.7469 - val_loss: 0.6734 - learning_rate: 5.0000e-05
# Epoch 199/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8075 - loss: 0.5874 - val_accuracy: 0.7469 - val_loss: 0.6730 - learning_rate: 5.0000e-05
# Epoch 200/200
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8138 - loss: 0.5865 - val_accuracy: 0.7454 - val_loss: 0.6715 - learning_rate: 5.0000e-05

# %% [markdown]
# ## Simple RNN

# %% [markdown]
# # Correr Modelos

# %% [markdown]
# **Test Set**

# %%
test_ids = df.loc[test_indices, "ID"]  # Get IDs for test split only
predict_and_save(model_dnn, X_test, test_ids, "dnn")
model_dnn.save("models/dnn.keras")
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %% [markdown]
# **Avaliação**

# %%
predict_and_save(model_dnn, X_professor, data_set_professor["ID"], "dnn_professor")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %% [markdown]
# ## Classification Reports

# %%
print(classification_report(y_test, model_dnn.predict(X_test) > 0.5))
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.64      0.70       420
#          1.0       0.68      0.80      0.73       391
#
#     accuracy                           0.72       811
#    macro avg       0.73      0.72      0.72       811
# weighted avg       0.73      0.72      0.72       811
